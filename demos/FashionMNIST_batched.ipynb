# %% [markdown]
# In this jupyter notebook, we show how EP3.0 can be used with any custom dataloader through fit_batch() module.
# Here we create a pytorch data loader for Fashion MNIST data set.
#
# First we create dataset and dataloader to visualize the dataset:

# %%
import torch
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

transform = transforms.Compose([transforms.ToTensor()])
trainset_tmp = datasets.FashionMNIST('~/', download=True, train=True, transform=transform)
trainloader_tmp = torch.utils.data.DataLoader(trainset_tmp, batch_size=10_000, shuffle=True)

# %%
plot_size = 2
fig, ax = plt.subplots(3, 4, figsize=(4*plot_size, 2*plot_size))
for i in range(12):
    image, label = next(iter(trainloader_tmp))
    ax[i//4][i%4].imshow(torch.squeeze(image[i,:]),cmap='gray')
    ax[i//4][i%4].axis('off')
    
plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0.2, hspace=.1)
plt.show()

# %% [markdown]
# Loading necessary packages from EP3.0:

# %%
from eigenpro3.utils import accuracy, load_dataset
from eigenpro3.datasets import CustomDataset
from eigenpro3.models import KernelModel
from eigenpro3.kernels import laplacian, ntk_relu
from eigenpro3.utils import accuracy,bottomrule, midrule 
from torch.nn.functional import one_hot
import copy

# %%
if torch.cuda.is_available():
    DEVICES = [torch.device(f'cuda:{i}') for i in range(torch.cuda.device_count())]
else:
    DEVICES = [torch.device('cpu')]
    
kernel_fn = lambda x, z: laplacian(x, z, bandwidth=5.0)
p = 5_000
s = 10_000
n_classes = 10


centers = trainset_tmp.data[torch.randperm(trainset_tmp.data.shape[0])[:p]].reshape(-1,28*28)/255.0
nystrom_samples = trainset_tmp.data[torch.randperm(trainset_tmp.data.shape[0])[:s]].reshape(-1,28*28)/255.0


model= KernelModel(n_classes, centers, kernel_fn, nystrom_samples=nystrom_samples,make_dataloader=False,
    devices = DEVICES)


##### creating new dataloader using optimal batchsize calculated based on Nystrom
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,)),transforms.Lambda(lambda x: torch.flatten(x))])
trainset = datasets.FashionMNIST('~/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=model.batch_size, shuffle=True)
testset = datasets.FashionMNIST('~/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      12 centers = trainset_tmp.data[torch.randperm(trainset_tmp.data.shape[0])[:p]].reshape(-1,28*28)/255.0
#      13 nystrom_samples = trainset_tmp.data[torch.randperm(trainset_tmp.data.shape[0])[:s]].reshape(-1,28*28)/255.0
# ---> 16 model= KernelModel(n_classes, centers, kernel_fn, nystrom_samples=nystrom_samples,make_dataloader=False,
#      17     devices = DEVICES,
#      18     multi_gpu=True)
#      21 ##### creating new dataloader using optimal batchsize calculated based on Nystrom
#      22 transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.1307,), (0.3081,)),transforms.Lambda(lambda x: torch.flatten(x))])
#
# TypeError: KernelModel.__init__() got an unexpected keyword argument 'multi_gpu'

# %%
iterations = 50
epoch = 0
accu_all = []
for _ in range(iterations):  
    batch_num = 0
    for (X_batch, y_batch) in trainloader:
        X_batch = X_batch 
        y_batch = one_hot(y_batch)
        ###### fitting the batch
        model.fit_batch(X_batch, y_batch)
        model.sync_gpus()
        torch.cuda.empty_cache()
        if (batch_num + 1)%2==0:
            print(f'epoch {epoch: 4d}\t batch {batch_num+1 :4d}')
        batch_num += 1
        del  X_batch, y_batch
    
    
    accu = accuracy(model.weights,model.centers,testloader,model.kernel,model.device_base)
    print(midrule)
    print(f'epoch {epoch+1:4d}        Test accuracy: {accu*100.:5.2f}%')
    accu_all.append(accu.item())
    print(bottomrule)
    epoch +=1
# Out:
# Projection SVD_time: 1.01 s, top_q: 741, top_eigval: 0.12, new top_eigval: 4.51e-04
# Projection setup: Nystrom size=2000, bs_gpu=5000, eta=1109.50, bs=2219, top_eigval=1.24e-01, beta=1.00
# ==================================================
# epoch    0	 batch    2
# epoch    0	 batch    4
# epoch    0	 batch    6
# epoch    0	 batch    8
# -------------------------
# epoch    1        Test accuracy: 68.42%
# ==================================================
# epoch    1	 batch    2
# epoch    1	 batch    4
# epoch    1	 batch    6
# epoch    1	 batch    8
# -------------------------
# epoch    2        Test accuracy: 71.27%
# ==================================================
# epoch    2	 batch    2
# epoch    2	 batch    4
# epoch    2	 batch    6
# epoch    2	 batch    8
# -------------------------
# epoch    3        Test accuracy: 73.07%
# ==================================================
# epoch    3	 batch    2
# epoch    3	 batch    4
# epoch    3	 batch    6
# epoch    3	 batch    8
# -------------------------
# epoch    4        Test accuracy: 73.88%
# ==================================================
# epoch    4	 batch    2
# epoch    4	 batch    4
# epoch    4	 batch    6
# epoch    4	 batch    8
# -------------------------
# epoch    5        Test accuracy: 74.95%
# ==================================================
# epoch    5	 batch    2
# epoch    5	 batch    4
# epoch    5	 batch    6
# epoch    5	 batch    8
# -------------------------
# epoch    6        Test accuracy: 75.56%
# ==================================================
# epoch    6	 batch    2
# epoch    6	 batch    4
# epoch    6	 batch    6
# epoch    6	 batch    8
# -------------------------
# epoch    7        Test accuracy: 76.09%
# ==================================================
# epoch    7	 batch    2
# epoch    7	 batch    4
# epoch    7	 batch    6
# epoch    7	 batch    8
# -------------------------
# epoch    8        Test accuracy: 76.54%
# ==================================================
# epoch    8	 batch    2
# epoch    8	 batch    4
# epoch    8	 batch    6
# epoch    8	 batch    8
# -------------------------
# epoch    9        Test accuracy: 76.72%
# ==================================================
# epoch    9	 batch    2
# epoch    9	 batch    4
# epoch    9	 batch    6
# epoch    9	 batch    8
# -------------------------
# epoch   10        Test accuracy: 77.03%
# ==================================================
# epoch   10	 batch    2
# epoch   10	 batch    4
# epoch   10	 batch    6
# epoch   10	 batch    8
# -------------------------
# epoch   11        Test accuracy: 77.31%
# ==================================================
# epoch   11	 batch    2
# epoch   11	 batch    4
# epoch   11	 batch    6
# epoch   11	 batch    8
# -------------------------
# epoch   12        Test accuracy: 77.39%
# ==================================================
# epoch   12	 batch    2
# epoch   12	 batch    4
# epoch   12	 batch    6
# epoch   12	 batch    8
# -------------------------
# epoch   13        Test accuracy: 77.64%
# ==================================================
# epoch   13	 batch    2
# epoch   13	 batch    4
# epoch   13	 batch    6
# epoch   13	 batch    8
# -------------------------
# epoch   14        Test accuracy: 77.83%
# ==================================================
# epoch   14	 batch    2
# epoch   14	 batch    4
# epoch   14	 batch    6
# epoch   14	 batch    8
# -------------------------
# epoch   15        Test accuracy: 77.94%
# ==================================================
# epoch   15	 batch    2
# epoch   15	 batch    4
# epoch   15	 batch    6
# epoch   15	 batch    8
# -------------------------
# epoch   16        Test accuracy: 78.17%
# ==================================================
# epoch   16	 batch    2
# epoch   16	 batch    4
# epoch   16	 batch    6
# epoch   16	 batch    8
# -------------------------
# epoch   17        Test accuracy: 78.23%
# ==================================================
# epoch   17	 batch    2
# epoch   17	 batch    4
# epoch   17	 batch    6
# epoch   17	 batch    8
# -------------------------
# epoch   18        Test accuracy: 78.40%
# ==================================================
# epoch   18	 batch    2
# epoch   18	 batch    4
# epoch   18	 batch    6
# epoch   18	 batch    8
# -------------------------
# epoch   19        Test accuracy: 78.49%
# ==================================================
# epoch   19	 batch    2
# epoch   19	 batch    4
# epoch   19	 batch    6
# epoch   19	 batch    8
# -------------------------
# epoch   20        Test accuracy: 78.74%
# ==================================================
# epoch   20	 batch    2
# epoch   20	 batch    4
# epoch   20	 batch    6
# epoch   20	 batch    8
# -------------------------
# epoch   21        Test accuracy: 78.82%
# ==================================================
# epoch   21	 batch    2
# epoch   21	 batch    4
# epoch   21	 batch    6
# epoch   21	 batch    8
# -------------------------
# epoch   22        Test accuracy: 78.96%
# ==================================================
# epoch   22	 batch    2
# epoch   22	 batch    4
# epoch   22	 batch    6
# epoch   22	 batch    8
# -------------------------
# epoch   23        Test accuracy: 79.03%
# ==================================================
# epoch   23	 batch    2
# epoch   23	 batch    4
# epoch   23	 batch    6
# epoch   23	 batch    8
# -------------------------
# epoch   24        Test accuracy: 79.12%
# ==================================================
# epoch   24	 batch    2
# epoch   24	 batch    4
# epoch   24	 batch    6
# epoch   24	 batch    8
# -------------------------
# epoch   25        Test accuracy: 79.23%
# ==================================================
# epoch   25	 batch    2
# epoch   25	 batch    4
# epoch   25	 batch    6
# epoch   25	 batch    8
# -------------------------
# epoch   26        Test accuracy: 79.30%
# ==================================================
# epoch   26	 batch    2
# epoch   26	 batch    4
# epoch   26	 batch    6
# epoch   26	 batch    8
# -------------------------
# epoch   27        Test accuracy: 79.49%
# ==================================================
# epoch   27	 batch    2
# epoch   27	 batch    4
# epoch   27	 batch    6
# epoch   27	 batch    8
# -------------------------
# epoch   28        Test accuracy: 79.55%
# ==================================================
# epoch   28	 batch    2
# epoch   28	 batch    4
# epoch   28	 batch    6
# epoch   28	 batch    8
# -------------------------
# epoch   29        Test accuracy: 79.58%
# ==================================================
# epoch   29	 batch    2
# epoch   29	 batch    4
# epoch   29	 batch    6
# epoch   29	 batch    8
# -------------------------
# epoch   30        Test accuracy: 79.67%
# ==================================================
# epoch   30	 batch    2
# epoch   30	 batch    4
# epoch   30	 batch    6
# epoch   30	 batch    8
# -------------------------
# epoch   31        Test accuracy: 79.75%
# ==================================================
# epoch   31	 batch    2
# epoch   31	 batch    4
# epoch   31	 batch    6
# epoch   31	 batch    8
# -------------------------
# epoch   32        Test accuracy: 79.77%
# ==================================================
# epoch   32	 batch    2
# epoch   32	 batch    4
# epoch   32	 batch    6
# epoch   32	 batch    8
# -------------------------
# epoch   33        Test accuracy: 79.86%
# ==================================================
# epoch   33	 batch    2
# epoch   33	 batch    4
# epoch   33	 batch    6
# epoch   33	 batch    8
# -------------------------
# epoch   34        Test accuracy: 79.94%
# ==================================================
# epoch   34	 batch    2
# epoch   34	 batch    4
# epoch   34	 batch    6
# epoch   34	 batch    8
# -------------------------
# epoch   35        Test accuracy: 80.03%
# ==================================================
# epoch   35	 batch    2
# epoch   35	 batch    4
# epoch   35	 batch    6
# epoch   35	 batch    8
# -------------------------
# epoch   36        Test accuracy: 80.03%
# ==================================================
# epoch   36	 batch    2
# epoch   36	 batch    4
# epoch   36	 batch    6
# epoch   36	 batch    8
# -------------------------
# epoch   37        Test accuracy: 80.09%
# ==================================================
# epoch   37	 batch    2
# epoch   37	 batch    4
# epoch   37	 batch    6
# epoch   37	 batch    8
# -------------------------
# epoch   38        Test accuracy: 80.16%
# ==================================================
# epoch   38	 batch    2
# epoch   38	 batch    4
# epoch   38	 batch    6
# epoch   38	 batch    8
# -------------------------
# epoch   39        Test accuracy: 80.23%
# ==================================================
# epoch   39	 batch    2
# epoch   39	 batch    4
# epoch   39	 batch    6
# epoch   39	 batch    8
# -------------------------
# epoch   40        Test accuracy: 80.30%
# ==================================================
# epoch   40	 batch    2
# epoch   40	 batch    4
# epoch   40	 batch    6
# epoch   40	 batch    8
# -------------------------
# epoch   41        Test accuracy: 80.36%
# ==================================================
# epoch   41	 batch    2
# epoch   41	 batch    4
# epoch   41	 batch    6
# epoch   41	 batch    8
# -------------------------
# epoch   42        Test accuracy: 80.38%
# ==================================================
# epoch   42	 batch    2
# epoch   42	 batch    4
# epoch   42	 batch    6
# epoch   42	 batch    8
# -------------------------
# epoch   43        Test accuracy: 80.47%
# ==================================================
# epoch   43	 batch    2
# epoch   43	 batch    4
# epoch   43	 batch    6
# epoch   43	 batch    8
# -------------------------
# epoch   44        Test accuracy: 80.51%
# ==================================================
# epoch   44	 batch    2
# epoch   44	 batch    4
# epoch   44	 batch    6
# epoch   44	 batch    8
# -------------------------
# epoch   45        Test accuracy: 80.56%
# ==================================================
# epoch   45	 batch    2
# epoch   45	 batch    4
# epoch   45	 batch    6
# epoch   45	 batch    8
# -------------------------
# epoch   46        Test accuracy: 80.59%
# ==================================================
# epoch   46	 batch    2
# epoch   46	 batch    4
# epoch   46	 batch    6
# epoch   46	 batch    8
# -------------------------
# epoch   47        Test accuracy: 80.62%
# ==================================================
# epoch   47	 batch    2
# epoch   47	 batch    4
# epoch   47	 batch    6
# epoch   47	 batch    8
# -------------------------
# epoch   48        Test accuracy: 80.68%
# ==================================================
# epoch   48	 batch    2
# epoch   48	 batch    4
# epoch   48	 batch    6
# epoch   48	 batch    8
# -------------------------
# epoch   49        Test accuracy: 80.67%
# ==================================================
# epoch   49	 batch    2
# epoch   49	 batch    4
# epoch   49	 batch    6
# epoch   49	 batch    8
# -------------------------
# epoch   50        Test accuracy: 80.65%
# ==================================================

# %%
plot_size = 5
fig, ax = plt.subplots(1, 1, figsize=(plot_size, plot_size))
ax.plot(range(len(accu_all)),accu_all)
ax.set_xlabel('epoch')
ax.set_ylabel('Test accuracy')
ax.set_title(r'FashionMNIST-$p=5,000$--$n=60,000$')
plt.show()

# %% [markdown]
# At the end, please note that the PyTorch DataLoader can be slow, and we recommend using simple batching techniques with manual methods instead. We provided the DataLoader based on PyTorch because it is widely used, but for large-scale experiments, we suggest avoiding it.
